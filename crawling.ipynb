# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd
from collections import defaultdict 

import csv
from tqdm import tqdm

# %%
import os
 
f = open("category.txt",encoding='utf-8')
line = f.readlines()
category_list = line
f.close

for i in range(len(category_list)):
    category_list[i] = category_list[i].strip()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd
from tqdm import tqdm

column = ['업무','공고번호-차수','분류','공고명','공고기관','수요기관','계약방법','입력일시','입찰마감일시','링크']
df = pd.DataFrame(columns=column)
try:
    driver = webdriver.Chrome('./chromedriver')
    driver.implicitly_wait(2)

    for query in category_list:

        
        
        driver.get('https://www.g2b.go.kr:8101/ep/tbid/tbidFwd.do')
        task_dict = {'용역': 'taskClCds5'}
        for task in task_dict.values():
            checkbox = driver.find_element(By.ID, task)
            checkbox.click()
        # ID값이 bidNm인 태그 가져오기
        bidNm = driver.find_element(By.ID, 'bidNm')
        # 내용을 삭제
        bidNm.clear()
        # 검색어에 문자열 전달
        bidNm.send_keys(query)
        bidNm.send_keys(Keys.RETURN)
        
        option_dict = {'검색기간 1달': 'setMonth1_1', '입찰마감건 제외': 'exceptEnd', '검색건수 표시': 'useTotalCount'}
        for option in option_dict.values():
            checkbox = driver.find_element(By.ID, option)
            checkbox.click()

        # 목록수 100건 선택 (드롭다운)
        print(1)
        recordcountperpage = driver.find_element(By.NAME,'recordCountPerPage')
        selector = Select(recordcountperpage)
        selector.select_by_value('100')

        search_button = driver.find_element(By.CLASS_NAME, 'btn_mdl')
        search_button.click()
        print(2)
        # 검색 결과 확인
        elem = driver.find_element(By.CLASS_NAME,'results')
        div_list = elem.find_elements(By.TAG_NAME, 'tr')

        # 리스트 형태로 검색결과 저장
        
        print(3)
        results = []
        links = []
        for div in tqdm(div_list):
            results.append(div.text)
            row_data = [div.text.split('\n')]
            a_tags = div.find_elements(By.TAG_NAME,'a')
            if a_tags:
                a_tag = a_tags[0]
                link = a_tag.get_attribute('href')
                row_data.append([link])
            # create a new DataFrame with the data from this row
            
            df_row = pd.DataFrame(row_data)
            # append it to the overall df using pd.concat()
            df = pd.concat([df, df_row], ignore_index=True)
                #df = df.assign(링크 =links)

except Exception as e:
    print(e)
finally:  
    driver.quit()
# Out:
# C:\Users\josuh\AppData\Local\Temp\ipykernel_7832\1709968033.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.06s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.04s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.03s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.05s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.04s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.04s/it]
# 1
# 2
# 3
# 100%|██████████| 6/6 [00:02<00:00,  2.65it/s]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.04s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.04s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:02<00:00,  1.04s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.05s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.04s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.25s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# 1
# 2
# 3
# 100%|██████████| 4/4 [00:02<00:00,  1.78it/s]
# 1
# 2
# 3
# 100%|██████████| 5/5 [00:02<00:00,  2.23it/s]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.05s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.06s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.06s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.05s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.05s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.06s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.06s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.07s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.06s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# 1
# 2
# 3
# 100%|██████████| 3/3 [00:02<00:00,  1.40it/s]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.05s/it]
# 1
# 2
# 3
# 100%|██████████| 8/8 [00:02<00:00,  3.32it/s]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.07s/it]
# 1
# 2
# 3
# 100%|██████████| 6/6 [00:02<00:00,  2.61it/s]
# 1
# 2
# 3
# 100%|██████████| 2/2 [00:04<00:00,  2.05s/it]
# 1
# 2
# 3
# 100%|██████████| 6/6 [00:02<00:00,  2.59it/s]
# 1
# 2
# 3
# 100%|██████████| 18/18 [00:03<00:00,  5.83it/s]

# %%
df = df[~df[0].isin(['업무 공고번호-차수 분류 공고명 공고기관 수요기관 계약방법 입력일시','검색된 데이터가 없습니다.'])]
df
# Out:
#       업무 공고번호-차수   분류  공고명 공고기관 수요기관 계약방법 입력일시 입찰마감일시   링크  \
# 13   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 14   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 15   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 16   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 17   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# ..   ...     ...  ...  ...  ...  ...  ...  ...    ...  ...
# 157  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 158  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 159  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 160  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
# 161  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  NaN
#
#                                                      0                 1  \
# 13                                                  용역  2023021508001-00
# 14   https://www.g2b.go.kr:8101/ep/tbid/serviceBidD...              None
# 15                                                  용역    20230222689-00
# 16   https://www.g2b.go.kr:8081/ep/invitation/publi...              None
# 17                                                  용역    20230210016-00
# ..                                                 ...               ...
# 157  https://www.g2b.go.kr:8081/ep/invitation/publi...              None
# 158                                                 용역    20230200105-00
# 159  https://www.g2b.go.kr:8081/ep/invitation/publi...              None
# 160                                                 용역    20230123003-00
# 161  https://www.g2b.go.kr:8081/ep/invitation/publi...              None
#
#         2                                                3            4  \
# 13     일반                    2023년 지속가능경영평가 대응 및 보고서 발간 용역       한국가스공사
# 14   None                                             None         None
# 15     일반                      2023년 서울특별시 투자·출연기관 경영평가 용역        서울특별시
# 16   None                                             None         None
# 17     일반  2022년도 기타공공기관 경영실적 평가 및 2023∼2024년 경영평가편람(안) 마련          환경부
# ..    ...                                              ...          ...
# 157  None                                             None         None
# 158    긴급                                 지능형 빅데이터 처리기술 연구  조달청 서울지방조달청
# 159  None                                             None         None
# 160    긴급                              빅데이터 플랫폼 기반 분석모델 개발          조달청
# 161  None                                             None         None
#
#           5              6                 7                   8     9
# 13   한국가스공사         제한(총액)  2023/02/15 14:10  (2023/02/27 16:00)   NaN
# 14     None           None              None                None   NaN
# 15    서울특별시  제한(총액)협상에의한계약  2023/02/15 10:51  (2023/02/28 17:00)   NaN
# 16     None           None              None                None   NaN
# 17      환경부  제한(총액)협상에의한계약  2023/02/07 18:15  (2023/02/20 12:00)   NaN
# ..      ...            ...               ...                 ...   ...
# 157    None           None              None                None   NaN
# 158    대검찰청  제한(총액)협상에의한계약  2023/02/01 15:00  (2023/02/17 10:00)    마감
# 159    None           None              None                None  None
# 160     관세청  제한(총액)협상에의한계약  2023/02/01 11:13  (2023/02/28 10:00)   NaN
# 161    None           None              None                None   NaN
#
# [104 rows x 20 columns]

# %%
column = ['업무','공고번호-차수','분류','공고명','공고기관','수요기관','계약방법','입력일시','입찰마감일시']
new_df = df.iloc[:,10:19]
new_df.columns = column

# %%
aa = new_df.iloc[::2,:]
with_link = pd.DataFrame(new_df.iloc[1::2,:]['업무'])
with_link = list(with_link['업무'])
aa['링크'] = with_link

aa['입력일시'] = pd.to_datetime(aa['입력일시'])
aa = aa.sort_values('입력일시',ascending=False)
aa = aa.drop_duplicates(['공고번호-차수'])
aa = aa.reset_index(drop=True)
# Out:
# C:\Users\josuh\AppData\Local\Temp\ipykernel_7832\1090609274.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['링크'] = with_link
# C:\Users\josuh\AppData\Local\Temp\ipykernel_7832\1090609274.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aa['입력일시'] = pd.to_datetime(aa['입력일시'])

# %%
from datetime import datetime 
today = datetime.today().strftime('%Y-%m-%d')

# %%
aa.to_excel(f'RA_Operational_공고_{today}.xlsx')

# %%
aa
# Out:
#     업무           공고번호-차수  분류  \
# 0   용역    20230226955-00  일반
# 1   용역    20230226859-00  긴급
# 2   용역    20230226754-00  긴급
# 3   용역    20230226709-00  긴급
# 4   용역    20230221735-01  변경
# 5   용역    20230225167-00  일반
# 6   용역    20230222712-00  일반
# 7   용역    20230224255-00  일반
# 8   용역    20230224472-00  일반
# 9   용역    20230223289-00  일반
# 10  용역    20230223410-00  일반
# 11  용역  2023021508001-00  일반
# 12  용역    20230222780-00  일반
# 13  용역    20230222227-00  긴급
# 14  용역    20230222689-00  일반
# 15  용역    20230220775-00  일반
# 16  용역    20230220715-00  긴급
# 17  용역     E102300225-00  일반
# 18  용역    20230218817-00  일반
# 19  용역    20230218688-00  긴급
# 20  용역    20230217131-00  일반
# 21  용역    20230209163-00  긴급
# 22  용역    20230213759-00  일반
# 23  용역    20230212911-00  일반
# 24  용역    20230212727-00  일반
# 25  용역    20230210374-00  긴급
# 26  용역    20230212070-00  긴급
# 27  용역    20230210606-00  일반
# 28  용역    20230211180-00  일반
# 29  용역    20230211000-00  일반
# 30  용역    20230210907-00  일반
# 31  용역    20230210658-00  일반
# 32  용역    20230210653-00  일반
# 33  용역    20230210016-00  일반
# 34  용역    20230209677-00  긴급
# 35  용역    20230209227-00  긴급
# 36  용역    20230208999-00  긴급
# 37  용역    20230208584-00  일반
# 38  용역    20230208578-00  일반
# 39  용역    20230205616-00  긴급
# 40  용역    20230207072-00  긴급
# 41  용역    20230206071-00  긴급
# 42  용역    20230206385-00  일반
# 43  용역    20230200105-00  긴급
# 44  용역    20230123003-00  긴급
# 45  용역    20230130038-00  일반
#
#                                                  공고명                 공고기관  \
# 0                               청렴수준 진단 및 청렴활동 지원 용역             한국인터넷진흥원
# 1                           2023년 특허 빅데이터 기반 산업혁신 지원                  특허청
# 2                            2023 국방빅데이터체계 유지보수 외주용역          국방부 한국국방연구원
# 3             2023년도 권역별 협동조합 지원기관 모니터링 및 성과평가 지원 용역           한국사회적기업진흥원
# 4                            중소기업 중대재해예방 컨설팅 지원사업 용역             경상남도 창원시
# 5                              2023년 중장기재무관리계획 수립 용역             서울주택도시공사
# 6                      2023년 대구광역시 민간위탁사무 운영성과 평가 용역                대구광역시
# 34          보건복지부 국립재활원  제한(총액)협상에의한계약 2023-02-07 17:37:00
# 35                서울특별시  제한(총액)협상에의한계약 2023-02-07 14:43:00
# 36              제주특별자치도  일반(총액)협상에의한계약 2023-02-07 13:45:00
# 37        질병관리청 국립보건연구원  일반(총액)협상에의한계약 2023-02-07 10:39:00
# 38            산림청 국립수목원  제한(총액)협상에의한계약 2023-02-07 10:37:00
# 39        한국식품산업클러스터진흥원  일반(총액)협상에의한계약 2023-02-06 21:19:00
# 40            서울특별시 관악구  제한(총액)협상에의한계약 2023-02-06 15:10:00
# 41    과학기술정보통신부 국립전파연구원  제한(총액)협상에의한계약 2023-02-06 13:49:00
# 42                서울특별시  일반(총액)협상에의한계약 2023-02-06 11:23:00
# 43                 대검찰청  제한(총액)협상에의한계약 2023-02-01 15:00:00
# 44                  관세청  제한(총액)협상에의한계약 2023-02-01 11:13:00
# 45                 전라남도  제한(총액)협상에의한계약 2023-01-30 15:31:00
#
#                 입찰마감일시                                                 링크
# 0                  (-)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 1   (2023/02/27 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 2   (2023/02/28 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 3   (2023/02/28 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 4   (2023/02/22 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 5                  (-)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 6   (2023/02/28 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 7   (2023/02/17 11:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 8   (2023/02/23 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 9   (2023/02/28 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 10  (2023/03/03 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 11  (2023/02/27 16:00)  https://www.g2b.go.kr:8101/ep/tbid/serviceBidD...
# 12  (2023/02/27 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 13  (2023/03/21 11:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 14  (2023/02/28 17:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 15  (2023/03/08 15:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 16                 (-)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 17  (2023/02/24 14:00)  https://www.g2b.go.kr:8101/ep/tbid/serviceBidD...
# 18  (2023/02/28 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 19  (2023/02/20 15:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 20  (2023/02/24 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 21  (2023/03/07 14:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 22  (2023/02/20 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 23  (2023/02/20 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 24  (2023/02/20 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 25  (2023/02/28 15:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 26  (2023/02/20 17:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 27  (2023/02/23 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 28  (2023/03/03 16:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 29  (2023/02/20 11:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 30  (2023/03/03 16:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 31  (2023/02/21 11:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 32  (2023/02/20 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 33  (2023/02/20 12:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 34  (2023/02/27 14:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 35  (2023/02/21 16:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 36                 (-)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 37  (2023/02/20 14:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 38  (2023/02/20 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 39  (2023/02/28 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 40  (2023/02/17 16:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 41  (2023/02/21 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 42  (2023/02/28 17:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 43  (2023/02/17 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 44  (2023/02/28 10:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...
# 45  (2023/02/21 17:00)  https://www.g2b.go.kr:8081/ep/invitation/publi...

# %%
import win32com.client as win32
from datetime import date
outlook = win32.gencache.EnsureDispatch('Outlook.Application')

# 새 메일 쓰기창 열기
new_mail = outlook.CreateItem(0)
new_mail.Subject = f"{date.today().strftime('%Y-%m-%d 나라장터 입찰 리스트')}"

#수신자
to_list = ['josuh@deloitte.com']
new_mail.To = ";".join(to_list)
#cc_list = ['yosohn@deloitte.com']
#new_mail.CC = ";".join(cc_list)
attachment1 = rf'C:\Users\josuh\Desktop\나라장터 크롤링\autocrawling\RA_Operational_공고_{today}.xlsx'
new_mail.Attachments.Add(Source=attachment1)


new_mail.Send()


# 아웃룩 종료
outlook.Quit()
